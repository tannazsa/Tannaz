# %% [markdown]
# <a href="https://colab.research.google.com/github/tannazsa/Tannaz/blob/master/TRAIN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-02e2b915-a539-4651-b0e7-ee1033c21971" name="files[]" multiple disabled />
#      <output id="result-02e2b915-a539-4651-b0e7-ee1033c21971">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Reviews0.csv to Reviews0.csv

# %%
data = pd.read_csv("Reviews0.csv",encoding='ISO-8859-1') # Read csv file into a pandas dataframe
data.head()
# Out:
#    SCORE  ...                                             REVIEW
# 0      2  ...  SPOILER: Gee, what a waste of money. I was unf...
# 1      4  ...  I would have thought that after the 15+ years ...
# 2     10  ...  Hollywood range action thriller and decent rom...
# 3      1  ...  I DO NOT RECOMMEND!!!!!!!!I wasn't expecting m...
# 4      4  ...  **WARNING: Contains plot spoilers**I don't nor...
#
# [5 rows x 3 columns]

# %%
data.info
# Out:
# <bound method DataFrame.info of     SCORE  ...                                             REVIEW
# 0       2  ...  SPOILER: Gee, what a waste of money. I was unf...
# 1       4  ...  I would have thought that after the 15+ years ...
# 2      10  ...  Hollywood range action thriller and decent rom...
# 3       1  ...  I DO NOT RECOMMEND!!!!!!!!I wasn't expecting m...
# 4       4  ...  **WARNING: Contains plot spoilers**I don't nor...
# 5       3  ...  Yeah I get that this is a big satirical commen...
# 6       5  ...  Fun movie, if not for the fact that the truth ...
# 7       7  ...  ...This movie would be a real treat...I enjoy'...
# 8       8  ...  Coco tells the story of young boy named Miguel...
# 9       6  ...  I bought this film on DVD on the strength of t...
# 10      8  ...  Let me tell you one thing:I have seen the sick...
# 11     10  ...  This is the Disney studio's return to 2D anima...
# 12      1  ...  The first half of the movie is super boring an...
# ...

# %%
tokens_without_sw_1=tokens_without_sw

for n in range(len(tokens_without_sw_1)):
  if tokens_without_sw_1[n] in ('"','.', " '" , "? ", "! ") :
    tokens_without_sw_1.pop(n)

print(tokens_without_sw_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-da43958e93ba> in <module>()
# ----> 1 tokens_without_sw_1=tokens_without_sw
#       2
#       3 for n in range(len(tokens_without_sw_1)):
#       4   if tokens_without_sw_1[n] in ('"','.', " '" , "? ", "! ") :
#       5     tokens_without_sw_1.pop(n)
#
# NameError: name 'tokens_without_sw' is not defined

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# ...

# %%
from nltk.tokenize import word_tokenize
reviews = data.REVIEW.str.cat(sep='')
tokens = word_tokenize(reviews)
print(tokens)
# Out:
# ['SPOILER', ':', 'Gee', ',', 'what', 'a', 'waste', 'of', 'money', '.', 'I', 'was', 'unfortunate', 'enough', 'to', 'catch', 'a', 'viewing', 'of', 'this', ',', 'uh', ',', 'film', 'on', 'its', 'opening', 'night', '.', 'And', 'I', 'honestly', 'had', 'high', 'expectations', '.', 'But', ',', 'not', 'unlike', 'Thor', ',', 'it', 'fell', 'very', 'VERY', 'short', '.', 'Here', 'are', 'a', 'few', 'of', 'the', 'problems', 'I', 'had', 'with', 'the', 'movie', '.', '1', '.', 'No', 'development', '.', 'With', 'EVERYTHING', '.', 'No', 'character', 'development', ',', 'no', 'plot', 'development', ',', 'and', 'no', 'emotional', 'development', '.', '2', '.', 'Mediocre', 'acting', '.', 'Enough', 'said', '.', '3', '.', 'It', 'was', 'too', 'over-the-top', '.', 'And', 'this', 'is', 'coming', 'from', 'a', 'Batman', 'Begins/Dark', 'Knight', 'fanatic', '.', 'Red', 'Skull', 'was', 'a', 'seriously', 'lousy', 'villain', '.', 'He', 'was', 'more', 'laughable', 'than', 'frightening', ',', 'especially', 'his', 'cheap'
# ...

# %%
vocabulary = set(tokens)
print(len(vocabulary))
frequency_dist = nltk.FreqDist(tokens)
sorted(frequency_dist,key=frequency_dist.__getitem__, reverse=True)[0:50]
# Out:
# 2056
# ['the',
#  '.',
#  ',',
#  'and',
#  'to',
#  'a',
#  'of',
#  'I',
#  'is',
#  'it',
#  'in',
#  'that',
#  'was',
#  'this',
#  "'s",
#  "''",
#  'but',
#  'for',
#  'movie',
#  'The',
#  'on',
#  '``',
#  "n't",
#  'as',
#  'be',
#  'with',
#  'his',
#  'her',
#  'film',
#  'or',
#  'just',
#  'they',
#  'not',
#  'you',
#  'what',
#  'are',
#  'so',
#  'It',
#  '?',
#  'have',
#  'one',
#  'from',
#  'me',
#  'at',
#  'very',
#  'has',
#  'do',
#  'who',
#  'Carol',
#  'had']

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
tokens = [w for w in tokens if not w in stop_words]
#print(type(tokens))
print(type(stopwords.words('english')))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# <class 'list'>

# %%
from nltk.tokenize import word_tokenize
text = reviews.lower()
text_tokens = word_tokenize(text)
tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]
print(tokens_without_sw)
# Out:
# ['spoiler', ':', 'gee', ',', 'waste', 'money', '.', 'unfortunate', 'enough', 'catch', 'viewing', ',', 'uh', ',', 'film', 'opening', 'night', '.', 'honestly', 'high', 'expectations', '.', ',', 'unlike', 'thor', ',', 'fell', 'short', '.', 'problems', 'movie', '.', '1.', 'development', '.', 'everything', '.', 'character', 'development', ',', 'plot', 'development', ',', 'emotional', 'development', '.', '2.', 'mediocre', 'acting', '.', 'enough', 'said', '.', '3.', 'over-the-top', '.', 'coming', 'batman', 'begins/dark', 'knight', 'fanatic', '.', 'red', 'skull', 'seriously', 'lousy', 'villain', '.', 'laughable', 'frightening', ',', 'especially', 'cheap', 'looking', '.', '4.', 'plot', '.', 'honestly', 'looking', 'forward', 'seeing', 'captain', 'america', 'fight', 'nazis', ',', 'hydra', '.', 'dumb', 'hydra', 'salute', 'made', 'gag', '.', "n't", 'sure', 'going', 'times', '.', 'magical', '``', 'cube', "''", '(', 'transformers', 'knockoff', '?', ')', "n't", 'settling', '.', 'expected', 'wwii', '
# ...

# %%
pos_tag = nltk.pos_tag(tokens_without_sw)
chunk = nltk.ne_chunk(pos_tag)
NE = [join(w for w, t in ele) for ele in chunk if isinstance(ele, nltk.Tree)]
print (NE)
# Out:
# []

# %%
freq = nltk.FreqDist(tokens_without_sw)
print (freq.most_common(10))
# Out:
# [(',', 287), ('.', 278), ("'s", 68), ("''", 63), ('movie', 48), ('``', 43), ("n't", 41), ('film', 38), ('?', 24), ('carol', 21)]

# %%
import pandas as pd
tokens_without_sw_pd=pd.DataFrame(tokens_without_sw)
tokens_without_sw_pd.to_csv('tokens_wo_sw.csv')
files.download('tokens_wo_sw.csv')

# %%
from collections import Counter 
total_counts = Counter()
for i in range(len(tokens_without_sw)):   
        for word in reviews[i]:
          print(word)
          total_counts[word] += 1
print(total_counts)
# Out:
# S
# P
# O
# I
# L
# E
# R
# :
#
# G
# e
# e
# ,
#
# w
# h
# a
# t
#
# a
#
# w
# a
# s
# t
# e
#
# o
# f
#
# m
# o
# n
# e
# y
# .
#
# I
#
# w
# a
# s
#
# u
# n
# f
# o
# r
# t
# u
# n
# a
# t
# e
#
# e
# n
# o
# u
# g
# h
#
# t
# o
#
# c
# a
# t
# c
# h
#
# a
#
# v
# i
# e
# w
# i
# n
# g
#
# o
# f
#
# t
# h
# i
# s
# ,
#
# u
# h
# ,
#
# f
# i
# l
# m
#
# o
# n
#
# i
# t
# s
#
# o
# p
# e
# n
# i
# n
# g
#
# n
# i
# g
# h
# t
# .
#
# A
# n
# d
#
# I
#
# h
# o
# n
# e
# s
# t
# l
# y
#
# h
# a
# d
#
# h
# i
# g
# h
#
# e
# x
# p
# e
# c
# t
# a
# t
# i
# o
# n
# s
# .
#
# B
# u
# t
# ,
#
# n
# o
# t
#
# u
# n
# l
# i
# k
# e
#
# T
# h
# o
# r
# ,
#
# i
# t
#
# f
# e
# l
# l
#
# v
# e
# r
# y
#
# V
# E
# R
# Y
#
# s
# h
# o
# r
# t
# .
#
# H
# e
# r
# e
#
# a
# r
# e
#
# a
#
# f
# e
# w
#
# o
# f
#
# t
# h
# e
#
# p
# r
# o
# b
# l
# e
# m
# s
#
# I
#
# h
# a
# d
#
# w
# i
# t
# h
#
# t
# h
# e
#
# m
# o
# v
# i
# e
# .
#
# 1
# .
#
# N
# o
#
# d
# e
# v
# e
# l
# o
# p
# m
# e
# n
# t
# ...

# %%
total_counts.most_common()
# Out:
# [(' ', 733),
#  ('e', 358),
#  ('t', 292),
#  ('a', 233),
#  ('o', 232),
#  ('i', 212),
#  ('n', 195),
#  ('s', 186),
#  ('h', 155),
#  ('r', 149),
#  ('l', 142),
#  ('d', 122),
#  ('u', 90),
#  ('.', 89),
#  ('c', 89),
#  ('m', 79),
#  ('w', 75),
#  ('g', 75),
#  ('f', 64),
#  ('y', 60),
#  ('p', 52),
#  (',', 40),
#  ('k', 39),
#  ('v', 36),
#  ('I', 30),
#  ('T', 28),
#  ('b', 27),
#  ('A', 24),
#  ("'", 24),
#  ('S', 16),
#  ('"', 16),
#  ('R', 13),
#  ('H', 12),
#  ('B', 11),
#  ('W', 9),
#  ('E', 8),
#  ('N', 8),
#  ('D', 8),
#  ('Y', 7),
#  ('-', 7),
#  ('x', 6),
#  ('C', 6),
#  ('1', 5),
#  ('!', 5),
#  ('j', 5),
#  ('P', 4),
#  ('L', 4),
#  ('G', 4),
#  ('M', 4),
#  ('K', 4),
#  ('z', 4),
#  ('U', 4),
#  ('O', 3),
#  ('4', 3),
#  ('0', 3),
#  ('V', 2),
#  ('2', 2),
#  ('/', 2),
#  ('(', 2),
#  ('?', 2),
#  (')', 2),
#  ('5', 2),
#  (':', 1),
#  ('3', 1),
#  ('6', 1),
#  ('q', 1),
#  ('7', 1),
#  ('8', 1),
#  ('9', 1),
#  ('+', 1),
#  ('J', 1)]

# %%
vocabulary = set(tokens)
print(len(vocabulary))
frequency_dist = nltk.FreqDist(tokens_without_sw)
sorted(frequency_dist,key=frequency_dist.__getitem__, reverse=True)[0:50]
# Out:
# 1943
# [',',
#  '.',
#  "'s",
#  "''",
#  'movie',
#  '``',
#  "n't",
#  'film',
#  '?',
#  'carol',
#  'well',
#  'would',
#  'like',
#  'much',
#  "'",
#  '(',
#  ')',
#  'see',
#  'good',
#  '!',
#  'really',
#  'first',
#  'story',
#  'get',
#  'time',
#  'watching',
#  'point',
#  'enough',
#  'little',
#  '...',
#  'even',
#  'action',
#  'way',
#  'love',
#  'made',
#  'best',
#  'scene',
#  'two',
#  'make',
#  'daughter',
#  'jules',
#  'know',
#  'funny',
#  'things',
#  'therese',
#  'never',
#  'whole',
#  'great',
#  'say',
#  'movies']

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
wordcloud = WordCloud(background_color='white',
                      max_words=100,
                      max_font_size=170,
                       ).generate_from_frequencies(frequency_dist)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
frequency_dist.most_common(50)
# Out:
# [(',', 287),
#  ('.', 278),
#  ("'s", 68),
#  ("''", 63),
#  ('movie', 48),
#  ('``', 43),
#  ("n't", 41),
#  ('film', 38),
#  ('?', 24),
#  ('carol', 21),
#  ('well', 20),
#  ('would', 20),
#  ('like', 19),
#  ('much', 19),
#  ("'", 19),
#  ('(', 18),
#  (')', 18),
#  ('see', 18),
#  ('good', 18),
#  ('!', 17),
#  ('really', 15),
#  ('first', 14),
#  ('story', 13),
#  ('get', 13),
#  ('time', 13),
#  ('watching', 12),
#  ('point', 12),
#  ('enough', 11),
#  ('little', 11),
#  ('...', 11),
#  ('even', 11),
#  ('action', 11),
#  ('way', 11),
#  ('love', 10),
#  ('made', 9),
#  ('best', 9),
#  ('scene', 9),
#  ('two', 9),
#  ('make', 9),
#  ('daughter', 9),
#  ('jules', 9),
#  ('know', 8),
#  ('funny', 8),
#  ('things', 8),
#  ('therese', 8),
#  ('never', 8),
#  ('whole', 8),
#  ('great', 8),
#  ('say', 8),
#  ('movies', 8)]

# %%
data
# Out:
#     SCORE  ...                                             REVIEW
# 0       2  ...  SPOILER: Gee, what a waste of money. I was unf...
# 1       4  ...  I would have thought that after the 15+ years ...
# 2      10  ...  Hollywood range action thriller and decent rom...
# 3       1  ...  I DO NOT RECOMMEND!!!!!!!!I wasn't expecting m...
# 4       4  ...  **WARNING: Contains plot spoilers**I don't nor...
# 5       3  ...  Yeah I get that this is a big satirical commen...
# 6       5  ...  Fun movie, if not for the fact that the truth ...
# 7       7  ...  ...This movie would be a real treat...I enjoy'...
# 8       8  ...  Coco tells the story of young boy named Miguel...
# 9       6  ...  I bought this film on DVD on the strength of t...
# 10      8  ...  Let me tell you one thing:I have seen the sick...
# 11     10  ...  This is the Disney studio's return to 2D anima...
# 12      1  ...  The first half of the movie is super boring an...
# ...

# %%
data['count'] = [len(i.split()) for i in data['REVIEW']]
print(data)
# Out:
#     SCORE  ... count
# 0       2  ...   672
# 1       4  ...   416
# 2      10  ...     7
# 3       1  ...   245
# 4       4  ...   835
# 5       3  ...   147
# 6       5  ...   121
# 7       7  ...   177
# 8       8  ...   368
# 9       6  ...   222
# 10      8  ...   164
# 11     10  ...   210
# 12      1  ...    39
# 13      3  ...   738
# 14      6  ...   986
# 15      1  ...   339
# 16      1  ...   195
# 17      8  ...   595
# 18      9  ...    83
# 19      8  ...    71
#
# [20 rows x 4 columns]

# %%
data
# Out:
#     SCORE  ... count
# 0       2  ...   672
# 1       4  ...   416
# 2      10  ...     7
# 3       1  ...   245
# 4       4  ...   835
# 5       3  ...   147
# 6       5  ...   121
# 7       7  ...   177
# 8       8  ...   368
# 9       6  ...   222
# 10      8  ...   164
# 11     10  ...   210
# 12      1  ...    39
# 13      3  ...   738
# 14      6  ...   986
# 15      1  ...   339
# 16      1  ...   195
# 17      8  ...   595
# 18      9  ...    83
# 19      8  ...    71
#
# [20 rows x 4 columns]

# %%
text = data.REVIEW.str.cat(sep='')
words = nltk.tokenize.word_tokenize(text)
fdist1 = nltk.FreqDist(words)

filtered_word_freq = dict((word, freq) for word, freq in fdist1.items() if not word.isdigit())

print(filtered_word_freq)
# Out:
# {'SPOILER': 1, ':': 7, 'Gee': 1, ',': 287, 'what': 30, 'a': 167, 'waste': 1, 'of': 154, 'money': 3, '.': 291, 'I': 104, 'was': 84, 'unfortunate': 1, 'enough': 10, 'to': 173, 'catch': 1, 'viewing': 1, 'this': 68, 'uh': 2, 'film': 35, 'on': 43, 'its': 4, 'opening': 1, 'night': 1, 'And': 16, 'honestly': 2, 'had': 20, 'high': 6, 'expectations': 1, 'But': 8, 'not': 33, 'unlike': 2, 'Thor': 2, 'it': 95, 'fell': 3, 'very': 22, 'VERY': 1, 'short': 2, 'Here': 1, 'are': 30, 'few': 3, 'the': 332, 'problems': 2, 'with': 38, 'movie': 48, 'No': 3, 'development': 4, 'With': 2, 'EVERYTHING': 1, 'character': 4, 'no': 14, 'plot': 7, 'and': 176, 'emotional': 4, 'Mediocre': 1, 'acting': 1, 'Enough': 1, 'said': 2, 'It': 26, 'too': 15, 'over-the-top': 1, 'is': 103, 'coming': 2, 'from': 23, 'Batman': 1, 'Begins/Dark': 1, 'Knight': 4, 'fanatic': 1, 'Red': 5, 'Skull': 5, 'seriously': 3, 'lousy': 1, 'villain': 1, 'He': 5, 'more': 17, 'laughable': 1, 'than': 18, 'frightening': 1, 'especially': 2, 'his': 38, 'c
# ...

# %%
from collections import Counter
import pandas as pd
sno = nltk.stem.SnowballStemmer('english')
s = data.REVIEW.str.cat(sep='')
s1 = s.split(' ')
d = pd.DataFrame(s1)
s2 = d[0].apply(lambda x: sno.stem(x))
unique =  Counter(s2)
print(unique)
# Out:
# Counter({'the': 373, 'and': 190, 'to': 172, 'a': 162, 'of': 154, 'it': 115, 'in': 99, 'is': 97, 'that': 91, 'i': 88, 'was': 76, 'this': 73, 'but': 59, 'for': 52, 'be': 48, 'on': 47, 'as': 42, 'with': 40, 'her': 39, 'they': 38, 'his': 37, 'movi': 37, 'not': 35, 'or': 35, 'just': 34, 'so': 34, 'what': 33, 'you': 33, 'film': 31, 'are': 30, 'he': 25, 'like': 25, 'have': 25, 'veri': 24, 'one': 24, 'at': 23, 'from': 22, 'see': 22, 'has': 21, 'she': 20, 'who': 20, 'me': 19, 'can': 19, 'get': 19, 'we': 19, 'had': 18, 'than': 18, 'some': 18, 'were': 18, 'do': 18, 'much': 18, 'would': 18, 'watch': 18, 'more': 17, 'there': 17, 'an': 17, 'if': 17, 'carol': 17, 'about': 16, 'good': 16, 'out': 16, 'their': 15, 'too': 14, 'realli': 14, 'when': 14, 'after': 14, 'will': 14, 'make': 14, 'no': 13, 'also': 13, 'thing': 13, 'by': 13, 'other': 13, 'point': 13, 'time': 13, 'de': 13, 'action': 12, 'becaus': 12, 'up': 12, 'scene': 12, 'all': 11, 'stori': 11, 'most': 11, 'even': 11, 'well': 11, 'our': 11, 'an
# ...

# %%
from collections import Counter 
total_counts = Counter()
for i in range(len(tokens_without_sw)):   
        for word in reviews[i]:
          print(word)
          total_counts[word] += 1
print(total_counts)
# Out:
# S
# P
# O
# I
# L
# E
# R
# :
#
# G
# e
# e
# ,
#
# w
# h
# a
# t
#
# a
#
# w
# a
# s
# t
# e
#
# o
# f
#
# m
# o
# n
# e
# y
# .
#
# I
#
# w
# a
# s
#
# u
# n
# f
# o
# r
# t
# u
# n
# a
# t
# e
#
# e
# n
# o
# u
# g
# h
#
# t
# o
#
# c
# a
# t
# c
# h
#
# a
#
# v
# i
# e
# w
# i
# n
# g
#
# o
# f
#
# t
# h
# i
# s
# ,
#
# u
# h
# ,
#
# f
# i
# l
# m
#
# o
# n
#
# i
# t
# s
#
# o
# p
# e
# n
# i
# n
# g
#
# n
# i
# g
# h
# t
# .
#
# A
# n
# d
#
# I
#
# h
# o
# n
# e
# s
# t
# l
# y
#
# h
# a
# d
#
# h
# i
# g
# h
#
# e
# x
# p
# e
# c
# t
# a
# t
# i
# o
# n
# s
# .
#
# B
# u
# t
# ,
#
# n
# o
# t
#
# u
# n
# l
# i
# k
# e
#
# T
# h
# o
# r
# ,
#
# i
# t
#
# f
# e
# l
# l
#
# v
# e
# r
# y
#
# V
# E
# R
# Y
#
# s
# h
# o
# r
# t
# .
#
# H
# e
# r
# e
#
# a
# r
# e
#
# a
#
# f
# e
# w
#
# o
# f
#
# t
# h
# e
#
# p
# r
# o
# b
# l
# e
# m
# s
#
# I
#
# h
# a
# d
#
# w
# i
# t
# h
#
# t
# h
# e
#
# m
# o
# v
# i
# e
# .
#
# 1
# .
#
# N
# o
#
# d
# e
# v
# e
# l
# o
# p
# m
# e
# n
# t
# ...

# %%
frequency_dist.most_common()
# Out:
# [(',', 287),
#  ('.', 278),
#  ("'s", 68),
#  ("''", 63),
#  ('movie', 48),
#  ('``', 43),
#  ("n't", 41),
#  ('film', 38),
#  ('?', 24),
#  ('carol', 21),
#  ('well', 20),
#  ('would', 20),
#  ('like', 19),
#  ('much', 19),
#  ("'", 19),
#  ('(', 18),
#  (')', 18),
#  ('see', 18),
#  ('good', 18),
#  ('!', 17),
#  ('really', 15),
#  ('first', 14),
#  ('story', 13),
#  ('get', 13),
#  ('time', 13),
#  ('watching', 12),
#  ('point', 12),
#  ('enough', 11),
#  ('little', 11),
#  ('...', 11),
#  ('even', 11),
#  ('action', 11),
#  ('way', 11),
#  ('love', 10),
#  ('made', 9),
#  ('best', 9),
#  ('scene', 9),
#  ('two', 9),
#  ('make', 9),
#  ('daughter', 9),
#  ('jules', 9),
#  ('know', 8),
#  ('funny', 8),
#  ('things', 8),
#  ('therese', 8),
#  ('never', 8),
#  ('whole', 8),
#  ('great', 8),
#  ('say', 8),
#  ('movies', 8),
#  ('niro', 8),
#  ('meyers', 8),
#  (':', 7),
#  ('plot', 7),
#  ('sure', 7),
#  ('better', 7),
#  ('seen', 7),
#  ('done', 7),
#  ("'m", 7),
#  ('bad', 7),
# ...

# %%
print(tokens_without_sw)
# Out:
# ['spoiler', ':', 'gee', ',', 'waste', 'money', '.', 'unfortunate', 'enough', 'catch', 'viewing', ',', 'uh', ',', 'film', 'opening', 'night', '.', 'honestly', 'high', 'expectations', '.', ',', 'unlike', 'thor', ',', 'fell', 'short', '.', 'problems', 'movie', '.', '1.', 'development', '.', 'everything', '.', 'character', 'development', ',', 'plot', 'development', ',', 'emotional', 'development', '.', '2.', 'mediocre', 'acting', '.', 'enough', 'said', '.', '3.', 'over-the-top', '.', 'coming', 'batman', 'begins/dark', 'knight', 'fanatic', '.', 'red', 'skull', 'seriously', 'lousy', 'villain', '.', 'laughable', 'frightening', ',', 'especially', 'cheap', 'looking', '.', '4.', 'plot', '.', 'honestly', 'looking', 'forward', 'seeing', 'captain', 'america', 'fight', 'nazis', ',', 'hydra', '.', 'dumb', 'hydra', 'salute', 'made', 'gag', '.', "n't", 'sure', 'going', 'times', '.', 'magical', '``', 'cube', "''", '(', 'transformers', 'knockoff', '?', ')', "n't", 'settling', '.', 'expected', 'wwii', '
# ...

# %%
DIC = data['REVIEW'].str.split().apply(Counter)
print(DIC)
# Out:
# 0     {'SPOILER:': 1, 'Gee,': 1, 'what': 3, 'a': 16,...
# 1     {'I': 3, 'would': 3, 'have': 2, 'thought': 1, ...
# 2     {'Hollywood': 1, 'range': 1, 'action': 1, 'thr...
# 3     {'I': 7, 'DO': 1, 'NOT': 1, 'RECOMMEND!!!!!!!!...
# 4     {'**WARNING:': 1, 'Contains': 1, 'plot': 2, 's...
# 5     {'Yeah': 1, 'I': 3, 'get': 1, 'that': 2, 'this...
# 6     {'Fun': 1, 'movie,': 1, 'if': 1, 'not': 1, 'fo...
# 7     {'...This': 1, 'movie': 3, 'would': 1, 'be': 2...
# 8     {'Coco': 3, 'tells': 1, 'the': 18, 'story': 1,...
# 9     {'I': 4, 'bought': 1, 'this': 3, 'film': 3, 'o...
# 10    {'Let': 1, 'me': 2, 'tell': 1, 'you': 2, 'one'...
# 11    {'This': 1, 'is': 4, 'the': 12, 'Disney': 5, '...
# 12    {'The': 1, 'first': 1, 'half': 1, 'of': 1, 'th...
# 13    {'I': 21, 'went': 1, 'into': 2, 'this': 11, 'm...
# 14    {'As': 1, 'far': 2, 'as': 14, 'on': 7, 'screen...
# 15    {'Based': 1, 'on': 2, 'the': 17, 'rating': 1, ...
# 16    {'Call': 1, 'it': 3, 'something': 1, 'else,': ...
# ...

# %%
data['count'] = [len(i.split())for i in data['REVIEW']]
print(data)
# Out:
#     SCORE  ... count
# 0       2  ...   672
# 1       4  ...   416
# 2      10  ...     7
# 3       1  ...   245
# 4       4  ...   835
# 5       3  ...   147
# 6       5  ...   121
# 7       7  ...   177
# 8       8  ...   368
# 9       6  ...   222
# 10      8  ...   164
# 11     10  ...   210
# 12      1  ...    39
# 13      3  ...   738
# 14      6  ...   986
# 15      1  ...   339
# 16      1  ...   195
# 17      8  ...   595
# 18      9  ...    83
# 19      8  ...    71
#
# [20 rows x 4 columns]

# %%
data["REVIEW"] = data["REVIEW"].str.lower()
data
# Out:
#     SCORE  ... count
# 0       2  ...   672
# 1       4  ...   416
# 2      10  ...     7
# 3       1  ...   245
# 4       4  ...   835
# 5       3  ...   147
# 6       5  ...   121
# 7       7  ...   177
# 8       8  ...   368
# 9       6  ...   222
# 10      8  ...   164
# 11     10  ...   210
# 12      1  ...    39
# 13      3  ...   738
# 14      6  ...   986
# 15      1  ...   339
# 16      1  ...   195
# 17      8  ...   595
# 18      9  ...    83
# 19      8  ...    71
#
# [20 rows x 4 columns]

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
REVW = data.REVIEW
RVW = pd.DataFrame(REVW)
RVW.columns = ["REVIEW"]
RVW['REVIEW_without_SW'] = RVW['REVIEW'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
print(RVW)
# Out:
#                                                REVIEW                                  REVIEW_without_SW
# 0   spoiler: gee, what a waste of money. i was unf...  spoiler: gee, waste money. unfortunate enough ...
# 1   i would have thought that after the 15+ years ...  would thought 15+ years since matrix consumers...
# 2   hollywood range action thriller and decent rom...     hollywood range action thriller decent romance
# 3   i do not recommend!!!!!!!!i wasn't expecting m...  recommend!!!!!!!!i expecting much this. like t...
# 4   **warning: contains plot spoilers**i don't nor...  **warning: contains plot spoilers**i normally ...
# 5   yeah i get that this is a big satirical commen...  yeah get big satirical commentary zombie movie...
# 6   fun movie, if not for the fact that the truth ...  fun movie, fact truth changed protect guilty. ...
# 7   ...this movie would be a real treat...i enjoy'...  ...this movie would real treat...i enjoy'd mov...
# ...

# %%
DIC2 = RVW['REVIEW_without_SW'].str.split().apply(Counter)
print(DIC2)
# Out:
# 0     {'spoiler:': 1, 'gee,': 1, 'waste': 1, 'money....
# 1     {'would': 3, 'thought': 1, '15+': 1, 'years': ...
# 2     {'hollywood': 1, 'range': 1, 'action': 1, 'thr...
# 3     {'recommend!!!!!!!!i': 1, 'expecting': 1, 'muc...
# 4     {'**warning:': 1, 'contains': 1, 'plot': 2, 's...
# 5     {'yeah': 1, 'get': 1, 'big': 2, 'satirical': 1...
# 6     {'fun': 1, 'movie,': 1, 'fact': 1, 'truth': 1,...
# 7     {'...this': 1, 'movie': 3, 'would': 1, 'real':...
# 8     {'coco': 3, 'tells': 1, 'story': 1, 'young': 1...
# 9     {'bought': 1, 'film': 3, 'dvd': 1, 'strength':...
# 10    {'let': 1, 'tell': 1, 'one': 1, 'thing:i': 1, ...
# 11    {'disney': 5, 'studio's': 1, 'return': 1, '2d'...
# 12    {'first': 1, 'half': 1, 'movie': 2, 'super': 1...
# 13    {'went': 1, 'movie': 7, 'decent': 1, 'hopes': ...
# 14    {'far': 2, 'screen': 2, 'pairings': 1, 'go,': ...
# 15    {'based': 1, 'rating': 1, 'one': 2, 'would': 2...
# 16    {'call': 1, 'something': 1, 'else,': 1, 'anyth...
# ...

# %%
RVW
# Out:
#                                                REVIEW                                  REVIEW_without_SW
# 0   spoiler: gee, what a waste of money. i was unf...  spoiler: gee, waste money. unfortunate enough ...
# 1   i would have thought that after the 15+ years ...  would thought 15+ years since matrix consumers...
# 2   hollywood range action thriller and decent rom...     hollywood range action thriller decent romance
# 3   i do not recommend!!!!!!!!i wasn't expecting m...  recommend!!!!!!!!i expecting much this. like t...
# 4   **warning: contains plot spoilers**i don't nor...  **warning: contains plot spoilers**i normally ...
# 5   yeah i get that this is a big satirical commen...  yeah get big satirical commentary zombie movie...
# 6   fun movie, if not for the fact that the truth ...  fun movie, fact truth changed protect guilty. ...
# 7   ...this movie would be a real treat...i enjoy'...  ...this movie would real treat...i enjoy'd mov...
# ...

# %%
RVWstr=RVW.to_string()
RVWstr
# Out:
# '                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     
# ...

# %%
SPLIT = RVWstr.replace(' ')
SPLIT
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-3822a929fce7> in <module>()
# ----> 1 SPLIT = RVWstr.replace(' ')
#       2 SPLIT
#
# TypeError: replace() takes at least 2 arguments (1 given)
